# %% [markdown]
# <a href="https://colab.research.google.com/github/xiepeijia/Machine-Learning-note/blob/master/matplotlib_otherstyle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 绘制散点图

# %%
# 0.准备数据
x = [225.98, 247.07, 253.14, 457.85, 241.58, 301.01,  20.67, 288.64,
       163.56, 120.06, 207.83, 342.75, 147.9 ,  53.06, 224.72,  29.51,
        21.61, 483.21, 245.25, 399.25, 343.35]
y = [196.63, 203.88, 210.75, 372.74, 202.41, 247.61,  24.9 , 239.34,
       140.32, 104.15, 176.84, 288.23, 128.79,  49.64, 191.74,  33.1 ,
        30.74, 400.02, 205.35, 330.64, 283.45]

# 1.画布
plt.figure(figsize=(20, 8), dpi=100)

# 2.绘制
plt.scatter(x, y)

# 3.显示
plt.show()

# %% [markdown]
# ### 柱状图

# %%
# 0.准备数据
# 电影名字
movie_name = ['雷神3：诸神黄昏','正义联盟','东方快车谋杀案','寻梦环游记','全球风暴','降魔传','追捕','七十七天','密战','狂兽','其它']
# 横坐标
x = range(len(movie_name))
# 票房数据
y = [73853,57767,22354,15969,14839,8725,8716,8318,7916,6764,52222]

# 1.创建
plt.figure(figsize=(20, 8), dpi=100)

# 2.绘制
plt.bar(x, y, color=['b','r','g','y','c','m','y','k','c','g','b'])

# 2.1 更改x轴刻度
plt.xticks(x, movie_name, fontsize=13)

# 2.2 标题
plt.title("电影票房收入对比")


# 3.显示
plt.show()
